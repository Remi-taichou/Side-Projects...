# %% [markdown]
# <a href="https://colab.research.google.com/github/Remi-taichou/Side-Projects.../blob/main/Even_Odd_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#num = 10
for num in range(0,11):
    if num % 2 == 0:
        print(f"{num} is an even number")
    else:
        print(f"{num} is an odd number")
# Out:
# 0 is an even number
# 1 is an odd number
# 2 is an even number
# 3 is an odd number
# 4 is an even number
# 5 is an odd number
# 6 is an even number
# 7 is an odd number
# 8 is an even number
# 9 is an odd number
# 10 is an even number

# %%
count = 0
while count<3:
  print("I am just a boy")
  count += 1
# Out:
# I am just a boy
# I am just a boy
# I am just a boy
