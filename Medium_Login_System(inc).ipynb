# %% [markdown]
# <a href="https://colab.research.google.com/github/Remi-taichou/Side-Projects.../blob/main/Medium_Login_System(inc).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count = 0

Username = input("Enter a username: " )
#Password = input("Enter a password:" )
while Username != "Remi" and Username != "Remilekun":
  print("Invalid Username, try again")
  Username = input("Enter a username:" )
print(f"Welcome {Username} 😎")

def login_attempts():
  global count
  count += 1

def sec_questions():
 if count < 2:
  sec_questions_prompt = input("Would you rather answer the security questions? ")
  if sec_questions_prompt == "Yes" or sec_questions_prompt == "yes":
    print("Security Questions")
    sec_questions_1 = input("1. Which state of origin is your mom from?:" )
    if sec_questions_1 == "Ilorin":
      print("Correct")
    else:
      print("Incorrect")
    sec_questions_2 = input("What is your favourite colour? ")
    if sec_questions_2 == "Blue":
      print("Correct")
    else:
      print("Incorrect")
  else:
    print("Logging in")



def reset_password():
  reset_password_prompt=("You have to reset your password? ")
  print(reset_password_prompt)
  new_password = input("Enter a new password: ")
  confirm_new_password = input("Confirm the new password: ")
  if new_password == confirm_new_password:
    print("Your password has been reset 🔃")
  else:
    print("Passwords does not match 🙅🏾")


def password():
 Password = input("Enter your password:" )
 while Password != "Remi123":
  if Password == "Remi123" :
    print("Welcome")
  else:
    print("Invalid Password 🙅🏾")
    login_attempts()
    sec_questions()
    reset_password()
    Password = input("Enter your password: " )
 print("Login Successful ✅")

password()
# Out:
# Enter a username: Remi
# Welcome Remi 😎
# Enter your password:123
# Invalid Password 🙅🏾
# Would you rather answer the security questions? Yes
# Security Questions
# 1. Which state of origin is your mom from?:Ilorin
# Correct
# What is your favourite colour? Blue
# Correct
# You have to reset your password?
# Enter a new password: 12345678
# Confirm the new password: 12345678
# Your password has been reset 🔃
# Enter your password: 12345678
# Invalid Password 🙅🏾
# You have to reset your password?
# Enter a new password: Remi123
# Confirm the new password: Remi123
# Your password has been reset 🔃
# Enter your password: Remi123
# Login Successful ✅

# %%
#allowed = ('Remi', 'Remilekun')

#username = input("Enter your username: ").strip()
#while username not in allowed:
  #print("Invalid username, try again")
 # username = input("Enter your username: ").strip()

#print(f"Welcome {username} 😎")





stored_password = 'Remi123!'


def password_flow():
  attempts = 0
  while attempts < 3:

    entered_password = input("Enter your password: ").strip()
    if entered_password == stored_password:
      print("Success ✅ , logging in")
      break

    else:
      attempts += 1
      if attempts == 1:
        print("You have 2 more attempts")
      if attempts == 2:
        print("You have 1 more attempt before you get locked out")
        sec_question_prompt = input("Do you want to answer security questions? (yes/no)")
        if sec_question_prompt == "Yes" or sec_question_prompt == "yes":
         sec_questions_1 = input("1. Which state of origin is your mom from?:" )
        if sec_questions_1 == "Ilorin":
         print("Correct")
        else:
         print("Incorrect")
         sec_questions_2 = input("What is your favourite colour? ")
          if sec_questions_2 == "Blue":
            print("Correct")
            print("Passsword reset available....")
          else:
            print("Incorrect")
          if sec_question_1 and sec_question_2 == True:
            new_password = input("Set a new password: ")
            confirm_password = input("Confirm your new password: ")
            if new_password == confirm_password:
              print("Your new password has been set!")
              stored_password == new_password
              entered_password = input("Enter your password: ").strip()
            else:
              print("The passwords dont match")
          else:
            print(" Your answers are invalid ")
      if attempts == 3:
        print("You have been locked out")
        break

#password_flow()

def security_questions_flow():

  if sec_question_1 and sec_question_2 == True:
    break
# Out:
# HEllo
# Enter your password: Remi123!
# Success ✅ , logging in
